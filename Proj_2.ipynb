# %%
# Dependencies
import pandas as pd
import numpy as np
import pygeoj

# %%
# Import our data into pandas from CSV
postcode_data_path = 'data/postcode-data.csv'
postcode_df = pd.read_csv(postcode_data_path, low_memory=False)

postcode_df.head()
# Out:
#                            Suburb State  Postcode
# 0  AUSTRALIAN NATIONAL UNIVERSITY   ACT     200.0
# 1                          DARWIN    NT     800.0
# 2                          DARWIN    NT     801.0
# 3                           PARAP    NT     804.0
# 4                           ALAWA    NT     810.0

# %%
# Import our data into pandas from CSV
SGU_data_path = 'data/SGU-SolarPanel.csv'
SGU_df = pd.read_csv(SGU_data_path, low_memory=False)
SGU_df.head()
# Out:
#   Small Generation Unit (SGU) - Solar Panel (Deemed)  \
# 0  Please be aware that RET legislation allows a ...
# 1                              Data as at 31/05/2021
# 2                   Small Unit Installation Postcode
# 3                                               0000
# 4                                               0200
#
#                                           Unnamed: 1  \
# 0                                                NaN
# 1                                                NaN
# 2  Previous Years (2001-2019) - Installations Qua...
# 3                                                  4
# 4                                                  1
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2  Previous Years (2001-2019) - SGU Rated Output ...
# 3                                              4.460
# 4                                              0.080
#
#                           Unnamed: 3                         Unnamed: 4  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2  Jan 2020 - Installations Quantity  Jan 2020 - SGU Rated Output In kW
# 3                                  0                              0.000
# 4                                  0                              0.000
#
#                           Unnamed: 5                         Unnamed: 6  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2  Feb 2020 - Installations Quantity  Feb 2020 - SGU Rated Output In kW
# 3                                  0                              0.000
# 4                                  0                              0.000
#
#                           Unnamed: 7                         Unnamed: 8  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2  Mar 2020 - Installations Quantity  Mar 2020 - SGU Rated Output In kW
# 3                                  0                              0.000
# 4                                  0                              0.000
#
#                           Unnamed: 9  ...                        Unnamed: 29  \
# 0                                NaN  ...                                NaN
# 1                                NaN  ...                                NaN
# 2  Apr 2020 - Installations Quantity  ...  Feb 2021 - Installations Quantity
# 3                                  0  ...                              0.000
# 4                                  0  ...                              0.000
#
#                          Unnamed: 30                        Unnamed: 31  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2  Feb 2021 - SGU Rated Output In kW  Mar 2021 - Installations Quantity
# 3                              0.000                              0.000
# 4                              0.000                              0.000
#
#                          Unnamed: 32                        Unnamed: 33  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2  Mar 2021 - SGU Rated Output In kW  Apr 2021 - Installations Quantity
# 3                              0.000                              0.000
# 4                              0.000                              0.000
#
#                          Unnamed: 34                        Unnamed: 35  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2  Apr 2021 - SGU Rated Output In kW  May 2021 - Installations Quantity
# 3                              0.000                                  0
# 4                              0.000                                  0
#
#                          Unnamed: 36                   Unnamed: 37  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2  May 2021 - SGU Rated Output In kW  Installations Quantity Total
# 3                              0.000                             4
# 4                              0.000                             1
#
#                     Unnamed: 38
# 0                           NaN
# 1                           NaN
# 2  SGU Rated Output In kW Total
# 3                          4.46
# 4                          0.08
#
# [5 rows x 39 columns]

# %%
SGU_df = pd.DataFrame(SGU_df.values[2:])
SGU_df
# Out:
#                                     0   \
# 0     Small Unit Installation Postcode
# 1                                 0000
# 2                                 0200
# 3                                 0800
# 4                                 0801
# ...                                ...
# 2798                              7469
# 2799                              7470
# 2800                              7802
# 2801                              8576
# 2802                              9729
#
#                                                      1   \
# 0     Previous Years (2001-2019) - Installations Qua...
# 1                                                     4
# 2                                                     1
# 3                                                    95
# 4                                                     7
# ...                                                 ...
# 2798                                                 35
# 2799                                                 35
# 2800                                                  1
# 2801                                                  2
# 2802                                                  1
#
#                                                      2   \
# 0     Previous Years (2001-2019) - SGU Rated Output ...
# 1                                                 4.460
# 2                                                 0.080
# 3                                             2,021.050
# 4                                               134.868
# ...                                                 ...
# 2798                                            125.445
# 2799                                            146.477
# 2800                                              2.450
# 2801                                              6.840
# 2802                                              0.875
#
#                                      3                                  4   \
# 0     Jan 2020 - Installations Quantity  Jan 2020 - SGU Rated Output In kW
# 1                                     0                              0.000
# 2                                     0                              0.000
# 3                                     1                             26.460
# 4                                     0                              0.000
# ...                                 ...                                ...
# 2798                                  0                              0.000
# 2799                                  0                              0.000
# 2800                                  0                              0.000
# 2801                                  0                              0.000
# 2802                                  0                              0.000
#
#                                      5                                  6   \
# 0     Feb 2020 - Installations Quantity  Feb 2020 - SGU Rated Output In kW
# 1                                     0                              0.000
# 2                                     0                              0.000
# 3                                     1                              9.100
# 4                                     0                              0.000
# ...                                 ...                                ...
# 2798                                  0                              0.000
# 2799                                  2                             13.000
# 2800                                  0                              0.000
# 2801                                  0                              0.000
# 2802                                  0                              0.000
#
#                                      7                                  8   \
# 0     Mar 2020 - Installations Quantity  Mar 2020 - SGU Rated Output In kW
# 1                                     0                              0.000
# 2                                     0                              0.000
# 3                                     0                              0.000
# 4                                     0                              0.000
# ...                                 ...                                ...
# 2798                                  0                              0.000
# 2799                                  0                              0.000
# 2800                                  0                              0.000
# 2801                                  0                              0.000
# 2802                                  0                              0.000
#
#                                      9   ...  \
# 0     Apr 2020 - Installations Quantity  ...
# 1                                     0  ...
# 2                                     0  ...
# 3                                     0  ...
# 4                                     0  ...
# ...                                 ...  ...
# 2798                                  0  ...
# 2799                                  1  ...
# 2800                                  0  ...
# 2801                                  0  ...
# 2802                                  0  ...
#
#                                      29                                 30  \
# 0     Feb 2021 - Installations Quantity  Feb 2021 - SGU Rated Output In kW
# 1                                 0.000                              0.000
# 2                                 0.000                              0.000
# 3                                 1.000                             35.200
# 4                                 0.000                              0.000
# ...                                 ...                                ...
# 2798                              0.000                              0.000
# 2799                              0.000                              0.000
# 2800                              0.000                              0.000
# 2801                              0.000                              0.000
# 2802                              0.000                              0.000
#
#                                      31                                 32  \
# 0     Mar 2021 - Installations Quantity  Mar 2021 - SGU Rated Output In kW
# 1                                 0.000                              0.000
# 2                                 0.000                              0.000
# 3                                 1.000                              6.630
# 4                                 0.000                              0.000
# ...                                 ...                                ...
# 2798                              2.000                             13.320
# 2799                              0.000                              0.000
# 2800                              0.000                              0.000
# 2801                              0.000                              0.000
# 2802                              0.000                              0.000
#
#                                      33                                 34  \
# 0     Apr 2021 - Installations Quantity  Apr 2021 - SGU Rated Output In kW
# 1                                 0.000                              0.000
# 2                                 0.000                              0.000
# 3                                 1.000                              6.660
# 4                                 0.000                              0.000
# ...                                 ...                                ...
# 2798                              0.000                              0.000
# 2799                              0.000                              0.000
# 2800                              0.000                              0.000
# 2801                              0.000                              0.000
# 2802                              0.000                              0.000
#
#                                      35                                 36  \
# 0     May 2021 - Installations Quantity  May 2021 - SGU Rated Output In kW
# 1                                     0                              0.000
# 2                                     0                              0.000
# 3                                     0                              0.000
# 4                                     0                              0.000
# ...                                 ...                                ...
# 2798                                  0                              0.000
# 2799                                  0                              0.000
# 2800                                  0                              0.000
# 2801                                  0                              0.000
# 2802                                  0                              0.000
#
#                                 37                            38
# 0     Installations Quantity Total  SGU Rated Output In kW Total
# 1                                4                          4.46
# 2                                1                          0.08
# 3                              109                       2595.58
# 4                                8                       234.858
# ...                            ...                           ...
# 2798                            37                       138.765
# 2799                            43                       193.257
# 2800                             1                          2.45
# 2801                             2                          6.84
# 2802                             1                         0.875
#
# [2803 rows x 39 columns]

# %%
# Set the column labels to equal the values in the fisrt row
SGU_df.columns = SGU_df.iloc[0]
SGU_df
# Out:
# 0     Small Unit Installation Postcode  \
# 0     Small Unit Installation Postcode
# 1                                 0000
# 2                                 0200
# 3                                 0800
# 4                                 0801
# ...                                ...
# 2798                              7469
# 2799                              7470
# 2800                              7802
# 2801                              8576
# 2802                              9729
#
# 0    Previous Years (2001-2019) - Installations Quantity  \
# 0     Previous Years (2001-2019) - Installations Qua...
# 1                                                     4
# 2                                                     1
# 3                                                    95
# 4                                                     7
# ...                                                 ...
# 2798                                                 35
# 2799                                                 35
# 2800                                                  1
# 2801                                                  2
# 2802                                                  1
#
# 0    Previous Years (2001-2019) - SGU Rated Output In kW  \
# 0     Previous Years (2001-2019) - SGU Rated Output ...
# 1                                                 4.460
# 2                                                 0.080
# 3                                             2,021.050
# 4                                               134.868
# ...                                                 ...
# 2798                                            125.445
# 2799                                            146.477
# 2800                                              2.450
# 2801                                              6.840
# 2802                                              0.875
#
# 0     Jan 2020 - Installations Quantity  Jan 2020 - SGU Rated Output In kW  \
# 0     Jan 2020 - Installations Quantity  Jan 2020 - SGU Rated Output In kW
# 1                                     0                              0.000
# 2                                     0                              0.000
# 3                                     1                             26.460
# 4                                     0                              0.000
# ...                                 ...                                ...
# 2798                                  0                              0.000
# 2799                                  0                              0.000
# 2800                                  0                              0.000
# 2801                                  0                              0.000
# 2802                                  0                              0.000
#
# 0     Feb 2020 - Installations Quantity  Feb 2020 - SGU Rated Output In kW  \
# 0     Feb 2020 - Installations Quantity  Feb 2020 - SGU Rated Output In kW
# 1                                     0                              0.000
# 2                                     0                              0.000
# 3                                     1                              9.100
# 4                                     0                              0.000
# ...                                 ...                                ...
# 2798                                  0                              0.000
# 2799                                  2                             13.000
# 2800                                  0                              0.000
# 2801                                  0                              0.000
# 2802                                  0                              0.000
#
# 0     Mar 2020 - Installations Quantity  Mar 2020 - SGU Rated Output In kW  \
# 0     Mar 2020 - Installations Quantity  Mar 2020 - SGU Rated Output In kW
# 1                                     0                              0.000
# 2                                     0                              0.000
# 3                                     0                              0.000
# 4                                     0                              0.000
# ...                                 ...                                ...
# 2798                                  0                              0.000
# 2799                                  0                              0.000
# 2800                                  0                              0.000
# 2801                                  0                              0.000
# 2802                                  0                              0.000
#
# 0     Apr 2020 - Installations Quantity  ...  \
# 0     Apr 2020 - Installations Quantity  ...
# 1                                     0  ...
# 2                                     0  ...
# 3                                     0  ...
# 4                                     0  ...
# ...                                 ...  ...
# 2798                                  0  ...
# 2799                                  1  ...
# 2800                                  0  ...
# 2801                                  0  ...
# 2802                                  0  ...
#
# 0     Feb 2021 - Installations Quantity  Feb 2021 - SGU Rated Output In kW  \
# 0     Feb 2021 - Installations Quantity  Feb 2021 - SGU Rated Output In kW
# 1                                 0.000                              0.000
# 2                                 0.000                              0.000
# 3                                 1.000                             35.200
# 4                                 0.000                              0.000
# ...                                 ...                                ...
# 2798                              0.000                              0.000
# 2799                              0.000                              0.000
# 2800                              0.000                              0.000
# 2801                              0.000                              0.000
# 2802                              0.000                              0.000
#
# 0     Mar 2021 - Installations Quantity  Mar 2021 - SGU Rated Output In kW  \
# 0     Mar 2021 - Installations Quantity  Mar 2021 - SGU Rated Output In kW
# 1                                 0.000                              0.000
# 2                                 0.000                              0.000
# 3                                 1.000                              6.630
# 4                                 0.000                              0.000
# ...                                 ...                                ...
# 2798                              2.000                             13.320
# 2799                              0.000                              0.000
# 2800                              0.000                              0.000
# 2801                              0.000                              0.000
# 2802                              0.000                              0.000
#
# 0     Apr 2021 - Installations Quantity  Apr 2021 - SGU Rated Output In kW  \
# 0     Apr 2021 - Installations Quantity  Apr 2021 - SGU Rated Output In kW
# 1                                 0.000                              0.000
# 2                                 0.000                              0.000
# 3                                 1.000                              6.660
# 4                                 0.000                              0.000
# ...                                 ...                                ...
# 2798                              0.000                              0.000
# 2799                              0.000                              0.000
# 2800                              0.000                              0.000
# 2801                              0.000                              0.000
# 2802                              0.000                              0.000
#
# 0     May 2021 - Installations Quantity  May 2021 - SGU Rated Output In kW  \
# 0     May 2021 - Installations Quantity  May 2021 - SGU Rated Output In kW
# 1                                     0                              0.000
# 2                                     0                              0.000
# 3                                     0                              0.000
# 4                                     0                              0.000
# ...                                 ...                                ...
# 2798                                  0                              0.000
# 2799                                  0                              0.000
# 2800                                  0                              0.000
# 2801                                  0                              0.000
# 2802                                  0                              0.000
#
# 0     Installations Quantity Total  SGU Rated Output In kW Total
# 0     Installations Quantity Total  SGU Rated Output In kW Total
# 1                                4                          4.46
# 2                                1                          0.08
# 3                              109                       2595.58
# 4                                8                       234.858
# ...                            ...                           ...
# 2798                            37                       138.765
# 2799                            43                       193.257
# 2800                             1                          2.45
# 2801                             2                          6.84
# 2802                             1                         0.875
#
# [2803 rows x 39 columns]

# %%
#  drop the first row
SGU_df = SGU_df.drop(SGU_df.index[0])
SGU_df
# Out:
# 0    Small Unit Installation Postcode  \
# 1                                0000
# 2                                0200
# 3                                0800
# 4                                0801
# 5                                0803
# ...                               ...
# 2798                             7469
# 2799                             7470
# 2800                             7802
# 2801                             8576
# 2802                             9729
#
# 0    Previous Years (2001-2019) - Installations Quantity  \
# 1                                                     4
# 2                                                     1
# 3                                                    95
# 4                                                     7
# 5                                                     2
# ...                                                 ...
# 2798                                                 35
# 2799                                                 35
# 2800                                                  1
# 2801                                                  2
# 2802                                                  1
#
# 0    Previous Years (2001-2019) - SGU Rated Output In kW  \
# 1                                                 4.460
# 2                                                 0.080
# 3                                             2,021.050
# 4                                               134.868
# 5                                                11.685
# ...                                                 ...
# 2798                                            125.445
# 2799                                            146.477
# 2800                                              2.450
# 2801                                              6.840
# 2802                                              0.875
#
# 0    Jan 2020 - Installations Quantity Jan 2020 - SGU Rated Output In kW  \
# 1                                    0                             0.000
# 2                                    0                             0.000
# 3                                    1                            26.460
# 4                                    0                             0.000
# 5                                    0                             0.000
# ...                                ...                               ...
# 2798                                 0                             0.000
# 2799                                 0                             0.000
# 2800                                 0                             0.000
# 2801                                 0                             0.000
# 2802                                 0                             0.000
#
# 0    Feb 2020 - Installations Quantity Feb 2020 - SGU Rated Output In kW  \
# 1                                    0                             0.000
# 2                                    0                             0.000
# 3                                    1                             9.100
# 4                                    0                             0.000
# 5                                    0                             0.000
# ...                                ...                               ...
# 2798                                 0                             0.000
# 2799                                 2                            13.000
# 2800                                 0                             0.000
# 2801                                 0                             0.000
# 2802                                 0                             0.000
#
# 0    Mar 2020 - Installations Quantity Mar 2020 - SGU Rated Output In kW  \
# 1                                    0                             0.000
# 2                                    0                             0.000
# 3                                    0                             0.000
# 4                                    0                             0.000
# 5                                    0                             0.000
# ...                                ...                               ...
# 2798                                 0                             0.000
# 2799                                 0                             0.000
# 2800                                 0                             0.000
# 2801                                 0                             0.000
# 2802                                 0                             0.000
#
# 0    Apr 2020 - Installations Quantity  ... Feb 2021 - Installations Quantity  \
# 1                                    0  ...                             0.000
# 2                                    0  ...                             0.000
# 3                                    0  ...                             1.000
# 4                                    0  ...                             0.000
# 5                                    0  ...                             0.000
# ...                                ...  ...                               ...
# 2798                                 0  ...                             0.000
# 2799                                 1  ...                             0.000
# 2800                                 0  ...                             0.000
# 2801                                 0  ...                             0.000
# 2802                                 0  ...                             0.000
#
# 0    Feb 2021 - SGU Rated Output In kW Mar 2021 - Installations Quantity  \
# 1                                0.000                             0.000
# 2                                0.000                             0.000
# 3                               35.200                             1.000
# 4                                0.000                             0.000
# 5                                0.000                             0.000
# ...                                ...                               ...
# 2798                             0.000                             2.000
# 2799                             0.000                             0.000
# 2800                             0.000                             0.000
# 2801                             0.000                             0.000
# 2802                             0.000                             0.000
#
# 0    Mar 2021 - SGU Rated Output In kW Apr 2021 - Installations Quantity  \
# 1                                0.000                             0.000
# 2                                0.000                             0.000
# 3                                6.630                             1.000
# 4                                0.000                             0.000
# 5                                0.000                             0.000
# ...                                ...                               ...
# 2798                            13.320                             0.000
# 2799                             0.000                             0.000
# 2800                             0.000                             0.000
# 2801                             0.000                             0.000
# 2802                             0.000                             0.000
#
# 0    Apr 2021 - SGU Rated Output In kW May 2021 - Installations Quantity  \
# 1                                0.000                                 0
# 2                                0.000                                 0
# 3                                6.660                                 0
# 4                                0.000                                 0
# 5                                0.000                                 0
# ...                                ...                               ...
# 2798                             0.000                                 0
# 2799                             0.000                                 0
# 2800                             0.000                                 0
# 2801                             0.000                                 0
# 2802                             0.000                                 0
#
# 0    May 2021 - SGU Rated Output In kW Installations Quantity Total  \
# 1                                0.000                            4
# 2                                0.000                            1
# 3                                0.000                          109
# 4                                0.000                            8
# 5                                0.000                            2
# ...                                ...                          ...
# 2798                             0.000                           37
# 2799                             0.000                           43
# 2800                             0.000                            1
# 2801                             0.000                            2
# 2802                             0.000                            1
#
# 0    SGU Rated Output In kW Total
# 1                            4.46
# 2                            0.08
# 3                         2595.58
# 4                         234.858
# 5                          11.685
# ...                           ...
# 2798                      138.765
# 2799                      193.257
# 2800                         2.45
# 2801                         6.84
# 2802                        0.875
#
# [2802 rows x 39 columns]

# %%
SGU_df = SGU_df.rename (columns ={'Small Unit Installation Postcode' :'Postcode'})
SGU_df
# Out:
# 0    Postcode Previous Years (2001-2019) - Installations Quantity  \
# 1        0000                                                  4
# 2        0200                                                  1
# 3        0800                                                 95
# 4        0801                                                  7
# 5        0803                                                  2
# ...       ...                                                ...
# 2798     7469                                                 35
# 2799     7470                                                 35
# 2800     7802                                                  1
# 2801     8576                                                  2
# 2802     9729                                                  1
#
# 0    Previous Years (2001-2019) - SGU Rated Output In kW  \
# 1                                                 4.460
# 2                                                 0.080
# 3                                             2,021.050
# 4                                               134.868
# 5                                                11.685
# ...                                                 ...
# 2798                                            125.445
# 2799                                            146.477
# 2800                                              2.450
# 2801                                              6.840
# 2802                                              0.875
#
# 0    Jan 2020 - Installations Quantity Jan 2020 - SGU Rated Output In kW  \
# 1                                    0                             0.000
# 2                                    0                             0.000
# 3                                    1                            26.460
# 4                                    0                             0.000
# 5                                    0                             0.000
# ...                                ...                               ...
# 2798                                 0                             0.000
# 2799                                 0                             0.000
# 2800                                 0                             0.000
# 2801                                 0                             0.000
# 2802                                 0                             0.000
#
# 0    Feb 2020 - Installations Quantity Feb 2020 - SGU Rated Output In kW  \
# 1                                    0                             0.000
# 2                                    0                             0.000
# 3                                    1                             9.100
# 4                                    0                             0.000
# 5                                    0                             0.000
# ...                                ...                               ...
# 2798                                 0                             0.000
# 2799                                 2                            13.000
# 2800                                 0                             0.000
# 2801                                 0                             0.000
# 2802                                 0                             0.000
#
# 0    Mar 2020 - Installations Quantity Mar 2020 - SGU Rated Output In kW  \
# 1                                    0                             0.000
# 2                                    0                             0.000
# 3                                    0                             0.000
# 4                                    0                             0.000
# 5                                    0                             0.000
# ...                                ...                               ...
# 2798                                 0                             0.000
# 2799                                 0                             0.000
# 2800                                 0                             0.000
# 2801                                 0                             0.000
# 2802                                 0                             0.000
#
# 0    Apr 2020 - Installations Quantity  ... Feb 2021 - Installations Quantity  \
# 1                                    0  ...                             0.000
# 2                                    0  ...                             0.000
# 3                                    0  ...                             1.000
# 4                                    0  ...                             0.000
# 5                                    0  ...                             0.000
# ...                                ...  ...                               ...
# 2798                                 0  ...                             0.000
# 2799                                 1  ...                             0.000
# 2800                                 0  ...                             0.000
# 2801                                 0  ...                             0.000
# 2802                                 0  ...                             0.000
#
# 0    Feb 2021 - SGU Rated Output In kW Mar 2021 - Installations Quantity  \
# 1                                0.000                             0.000
# 2                                0.000                             0.000
# 3                               35.200                             1.000
# 4                                0.000                             0.000
# 5                                0.000                             0.000
# ...                                ...                               ...
# 2798                             0.000                             2.000
# 2799                             0.000                             0.000
# 2800                             0.000                             0.000
# 2801                             0.000                             0.000
# 2802                             0.000                             0.000
#
# 0    Mar 2021 - SGU Rated Output In kW Apr 2021 - Installations Quantity  \
# 1                                0.000                             0.000
# 2                                0.000                             0.000
# 3                                6.630                             1.000
# 4                                0.000                             0.000
# 5                                0.000                             0.000
# ...                                ...                               ...
# 2798                            13.320                             0.000
# 2799                             0.000                             0.000
# 2800                             0.000                             0.000
# 2801                             0.000                             0.000
# 2802                             0.000                             0.000
#
# 0    Apr 2021 - SGU Rated Output In kW May 2021 - Installations Quantity  \
# 1                                0.000                                 0
# 2                                0.000                                 0
# 3                                6.660                                 0
# 4                                0.000                                 0
# 5                                0.000                                 0
# ...                                ...                               ...
# 2798                             0.000                                 0
# 2799                             0.000                                 0
# 2800                             0.000                                 0
# 2801                             0.000                                 0
# 2802                             0.000                                 0
#
# 0    May 2021 - SGU Rated Output In kW Installations Quantity Total  \
# 1                                0.000                            4
# 2                                0.000                            1
# 3                                0.000                          109
# 4                                0.000                            8
# 5                                0.000                            2
# ...                                ...                          ...
# 2798                             0.000                           37
# 2799                             0.000                           43
# 2800                             0.000                            1
# 2801                             0.000                            2
# 2802                             0.000                            1
#
# 0    SGU Rated Output In kW Total
# 1                            4.46
# 2                            0.08
# 3                         2595.58
# 4                         234.858
# 5                          11.685
# ...                           ...
# 2798                      138.765
# 2799                      193.257
# 2800                         2.45
# 2801                         6.84
# 2802                        0.875
#
# [2802 rows x 39 columns]

# %%
data = pygeoj.load('data/australian-suburbs.geojson')

properties_arr = []

for feature in data :
    properties_arr.append(feature.properties)

# %%
len(properties_arr)
# Out:
# 16288

# %%
properties_arr
# Out:
# [{'lc_ply_pid': 16479,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT216',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FORREST',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16483,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT217',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'KINGSTON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16414,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT330',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'GARRAN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16404,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT446',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'DUFFY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16406,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT447',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HOLDER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16454,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT552',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'GIRALANG',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16462,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT558',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MACQUARIE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16461,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT569',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MACGREGOR',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16451,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT574',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'EVATT',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16402,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT602',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'WANNIASSA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16400,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT607',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'RICHARDSON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16501,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT611',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CALWELL',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16503,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT613',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CONDER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16514,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT915',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'JERRABOMBERRA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16119,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT919',
#   'act_locali': '2015-05-08Z',
#   'act_loca_1': None,
#   'act_loca_2': 'COTTER RIVER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16068,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT927',
#   'act_locali': '2013-03-27Z',
#   'act_loca_1': None,
#   'act_loca_2': 'URIARRA VILLAGE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16484,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT101',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'LYNEHAM',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16486,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT103',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': "O'CONNOR",
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16472,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT106',
#   'act_locali': '2007-01-31Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BRADDON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16499,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT125',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'WATSON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16474,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT213',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CAPITAL HILL',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16471,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT214',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BARTON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16417,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT329',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'LYONS',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16422,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT332',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'TORRENS',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16405,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT443',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FISHER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16407,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT445',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'RIVETT',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16448,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT559',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BELCONNEN',
#   'act_loca_3': None,
#   'act_loca_4': 2617,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16441,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT578',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'DUNLOP',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16460,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT580',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'LAWSON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16397,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT606',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MACARTHUR',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16507,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT615',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'GREENWAY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16443,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT707',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'AMAROO',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16492,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT710',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'GUNGAHLIN',
#   'act_loca_3': None,
#   'act_loca_4': 2912,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16497,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT803',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'SYMONSTON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16437,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT907',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'WRIGHT',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16516,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT908',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CANBERRA CENTRAL',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16513,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT910',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'WODEN VALLEY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16518,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT911',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'WESTON CREEK',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16509,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT913',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'TUGGERANONG',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16510,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT917',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'STROMLO',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16424,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT932',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MONCRIEFF',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16487,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT211',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'PARKES',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16480,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT219',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FYSHWICK',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16498,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT251',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'PIALLIGO',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16413,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT334',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FARRER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16421,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT338',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'PHILLIP',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16408,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT448',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'STIRLING',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16505,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT608',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'GILMORE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16445,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT614',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BANKS',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16446,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT616',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'GORDON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16428,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT711',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HARRISON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16496,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT901',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HALL',
#   'act_loca_3': None,
#   'act_loca_4': 2618,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16429,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT904',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CRACE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16131,
#   'dt_create': '2013-08-26Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT914',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'GUNGAHLIN',
#   'act_loca_3': None,
#   'act_loca_4': 9999,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16124,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT924',
#   'act_locali': '2014-03-31Z',
#   'act_loca_1': None,
#   'act_loca_2': 'TENNENT',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16519,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT926',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MOLONGLO VALLEY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16423,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT934',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'TAYLOR',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16001,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT109',
#   'act_locali': '2013-03-27Z',
#   'act_loca_1': None,
#   'act_loca_2': 'REID',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16473,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT110',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CAMPBELL',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16485,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT218',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'NARRABUNDAH',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16410,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT441',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'WESTON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16453,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT571',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FLYNN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16464,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT572',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MELBA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16467,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT576',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'SPENCE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16398,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT603',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MONASH',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16495,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT709',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'PALMERSTON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16512,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT920',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MOUNT CLEAR',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16272,
#   'dt_create': '2017-03-03Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT925',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BOOTH',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16439,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT929',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'DENMAN PROSPECT',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16469,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT107',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'ACTON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16481,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT220',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'GRIFFITH',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16420,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT331',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'PEARCE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16416,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT336',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'ISAACS',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16411,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT337',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CHIFLEY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16449,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT555',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BRUCE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16455,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT563',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HAWKER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16440,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT570',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CHARNWOOD',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16442,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT577',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FRASER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16506,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT604',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'GOWRIE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16502,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT609',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CHISHOLM',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16508,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT612',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'ISABELLA PLAINS',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16399,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT623',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'OXLEY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16425,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT903',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CASEY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16433,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT935',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'STRATHNAIRN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16477,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT102',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'DICKSON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16482,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT126',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HACKETT',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16488,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT221',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'RED HILL',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16418,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT333',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MAWSON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16457,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT568',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HOLT',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16099,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT659',
#   'act_locali': '2013-03-27Z',
#   'act_loca_1': None,
#   'act_loca_2': 'THARWA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16431,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT719',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BONNER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16430,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT902',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FRANKLIN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16051,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT905',
#   'act_locali': '2012-05-02Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BEARD',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16435,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT906',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'COOMBS',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16118,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT918',
#   'act_locali': '2015-05-08Z',
#   'act_loca_1': None,
#   'act_loca_2': 'COREE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16427,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT933',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'THROSBY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16470,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT104',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'AINSLIE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16490,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT105',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'TURNER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16475,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT108',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CITY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16415,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT327',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HUGHES',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16412,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT328',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CURTIN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16409,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT442',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'WARAMANGA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16447,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT556',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'ARANDA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16466,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT564',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'SCULLIN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16456,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT567',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HIGGINS',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16504,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT605',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FADDEN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16444,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT701',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MITCHELL',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16494,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT708',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'NICHOLLS',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16025,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT802',
#   'act_locali': '2013-03-27Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HUME',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16515,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT912',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BELCONNEN',
#   'act_loca_3': None,
#   'act_loca_4': 9999,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16132,
#   'dt_create': '2013-08-26Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT916',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'HALL',
#   'act_loca_3': None,
#   'act_loca_4': 9999,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16511,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT921',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'KOWEN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16122,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT922',
#   'act_locali': '2014-03-31Z',
#   'act_loca_1': None,
#   'act_loca_2': 'RENDEZVOUS CREEK',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16123,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT923',
#   'act_locali': '2015-11-09Z',
#   'act_loca_1': None,
#   'act_loca_2': 'PADDYS RIVER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16489,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT122',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'RUSSELL',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16478,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT124',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'DOWNER',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16491,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT212',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'YARRALUMLA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16476,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT215',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'DEAKIN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16419,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT335',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': "O'MALLEY",
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16403,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT444',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CHAPMAN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16458,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT553',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'KALEEN',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16450,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT557',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'COOK',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16452,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT560',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FLOREY',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16465,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT561',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'PAGE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16468,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT562',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'WEETANGERA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16459,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT566',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'LATHAM',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16463,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT575',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MCKELLAR',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16396,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT601',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'KAMBAH',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16401,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT610',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'THEODORE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16500,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT619',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'BONYTHON',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16493,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT706',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'NGUNNAWAL',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16426,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT716',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'FORDE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 15996,
#   'dt_create': '2013-05-27Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT801',
#   'act_locali': '2013-06-27Z',
#   'act_loca_1': None,
#   'act_loca_2': 'OAKS ESTATE',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16517,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT909',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MAJURA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'D',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16432,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT928',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'JACKA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16438,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT930',
#   'act_locali': '2017-11-01Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MOLONGLO',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16436,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT931',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'CANBERRA AIRPORT',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 16434,
#   'dt_create': '2017-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'ACT936',
#   'act_locali': '2017-10-03Z',
#   'act_loca_1': None,
#   'act_loca_2': 'MACNAMARA',
#   'act_loca_3': None,
#   'act_loca_4': None,
#   'act_loca_5': 'G',
#   'act_loca_6': None,
#   'act_loca_7': 8},
#  {'lc_ply_pid': 25113,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1147',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'CROYDON PARK',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25065,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2557',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'MAYFIELD WEST',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25115,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW797',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'CAMPSIE',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 16193,
#   'dt_create': '2011-11-22Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4136',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'WALLACETOWN',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24884,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW812',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'CANTERBURY',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24903,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1012',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'CONCORD',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 19660,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4098',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'UTUNGUN',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25101,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4391',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'WOLLSTONECRAFT',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 19669,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3304',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'PUTNEY',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24941,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2370',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'LITHGOW',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24793,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3819',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'TEN MILE HOLLOW',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24750,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3961',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'TOUKLEY',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24966,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4177',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'WARATAH WEST',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20524,
#   'dt_create': '2013-03-07Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2941',
#   'nsw_locali': '2013-04-30Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'NAUGHTONS GAP',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20525,
#   'dt_create': '2013-03-07Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3013',
#   'nsw_locali': '2013-04-30Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'NORTH CASINO',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 10755,
#   'dt_create': '2009-08-31Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW58',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'ANGOURIE',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20278,
#   'dt_create': '2013-03-07Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW948',
#   'nsw_locali': '2013-04-30Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'CLOTHIERS CREEK',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20526,
#   'dt_create': '2013-03-07Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2153',
#   'nsw_locali': '2013-04-30Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'KILLARA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20978,
#   'dt_create': '2013-08-26Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3812',
#   'nsw_locali': '2013-11-01Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'TEA GARDENS',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20347,
#   'dt_create': '2013-03-07Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1643',
#   'nsw_locali': '2013-04-30Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'GILMANDYKE',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 10414,
#   'dt_create': '2009-08-31Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3268',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'PONTO',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20983,
#   'dt_create': '2013-08-26Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1401',
#   'nsw_locali': '2013-11-01Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'EDROM',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20984,
#   'dt_create': '2013-08-26Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4415',
#   'nsw_locali': '2013-11-01Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'WOODFORD ISLAND',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20985,
#   'dt_create': '2013-08-26Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2139',
#   'nsw_locali': '2013-11-01Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'KIAH',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24892,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3820',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'TENAMBIT',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24679,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3619',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'SOUTH GUYRA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24743,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3504',
#   'nsw_locali': '2012-07-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'SANDBAR',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 15923,
#   'dt_create': '2011-11-22Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3131',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'OSWALD',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24742,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW424',
#   'nsw_locali': '2014-11-07Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BLUEYS BEACH',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24696,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW433',
#   'nsw_locali': '2015-11-10Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BOBS CREEK',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24911,
#   'dt_create': '2015-09-03Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3362',
# ...
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'TULLARWALLA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 19032,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4215',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'WASHPOOL',
#   'nsw_loca_3': None,
#   'nsw_loca_4': 2460,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 19034,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2219',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'KOREELAH',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 21976,
#   'dt_create': '2013-11-25Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4071',
#   'nsw_locali': '2014-02-01Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'UPPER MAIN ARM',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25325,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW285',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BEN LOMOND',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 26691,
#   'dt_create': '2016-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1609',
#   'nsw_locali': '2016-11-11Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'GAROO',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 26513,
#   'dt_create': '2016-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3651',
#   'nsw_locali': '2016-11-11Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'SPRING PLAINS',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25188,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4028',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'TWIN RIVERS',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25336,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW99',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'ASHFORD',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 26514,
#   'dt_create': '2016-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2049',
#   'nsw_locali': '2016-11-11Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'JEWS LAGOON',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25322,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2479',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'MALLAN',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25371,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW204',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BAROOGA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25295,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW341',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BIDGEEMIA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25149,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2755',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'MORUNDAH',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 19313,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1300',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'DOYALSON NORTH',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25148,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1092',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'COROBIMILLA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 26828,
#   'dt_create': '2016-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW120',
#   'nsw_locali': '2016-11-11Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BAAN BAA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 13093,
#   'dt_create': '2010-11-23Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2797',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'MOUNT LINDSEY',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 19314,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4145',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'WALLARAH',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 26813,
#   'dt_create': '2016-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW669',
#   'nsw_locali': '2016-11-11Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BULLAWA CREEK',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 26741,
#   'dt_create': '2016-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3957',
#   'nsw_locali': '2016-11-11Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'TORRYBURN',
#   'nsw_loca_3': None,
#   'nsw_loca_4': 2358,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 26555,
#   'dt_create': '2016-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW147',
#   'nsw_locali': '2016-11-11Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BALDERSLEIGH',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25252,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3109',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'OLD JUNEE',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25470,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2052',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'JIMENBUEN',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25426,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW712',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BURRA CREEK',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25145,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2698',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'MONGA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25514,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW554',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BRAIDWOOD',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25482,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4328',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'WILLBRIGGIE',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25498,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW177',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BANKSIA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25212,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1450',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'ERMINGTON',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25340,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1179',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'CURL CURL',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 18505,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3361',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'RED RANGE',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25813,
#   'dt_create': '2016-02-29Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2713',
#   'nsw_locali': '2016-05-08Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'MOOLARBEN',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 18508,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW238',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BEAN CREEK',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25628,
#   'dt_create': '2016-02-29Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2889',
#   'nsw_locali': '2016-05-08Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'MURRURUNDI',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 21808,
#   'dt_create': '2013-11-25Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1507',
#   'nsw_locali': '2014-02-01Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'FARGUNYAH',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25629,
#   'dt_create': '2016-02-29Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW410',
#   'nsw_locali': '2016-05-08Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BLANDFORD',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 18513,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2019',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'JAGUNGAL WILDERNESS',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 8757,
#   'dt_create': '2009-06-05Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1321',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'DUMBUDGERY',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 18355,
#   'dt_create': '2012-08-15Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1004',
#   'nsw_locali': '2012-10-30Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'COMBO',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 12852,
#   'dt_create': '2010-08-13Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3127',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'ORIENT POINT',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 21809,
#   'dt_create': '2013-11-25Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2392',
#   'nsw_locali': '2014-02-01Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'LOCKHART',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 14811,
#   'dt_create': '2011-05-17Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1209',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'DANGAR ISLAND',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 22968,
#   'dt_create': '2014-08-27Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1721',
#   'nsw_locali': '2014-11-07Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'GOODWOOD ISLAND',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 17626,
#   'dt_create': '2012-05-15Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3351',
#   'nsw_locali': '2012-07-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'RAWDON VALE',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 26448,
#   'dt_create': '2016-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1877',
#   'nsw_locali': '2016-11-11Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'HARRINGTON PARK',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 18977,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW553',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BRAEMAR BAY',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 15047,
#   'dt_create': '2011-09-15Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW5021',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BURRANEER',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 24156,
#   'dt_create': '2015-02-24Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4524',
#   'nsw_locali': '2015-05-08Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'YARROWITCH',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 26758,
#   'dt_create': '2016-09-12Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW795',
#   'nsw_locali': '2016-11-11Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'CAMPBELLTOWN',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 18979,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2689',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'MOLLYAN',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 18980,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW4371',
#   'nsw_locali': '2012-02-04Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'WIRRAGULLA',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 20881,
#   'dt_create': '2013-06-06Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW642',
#   'nsw_locali': '2013-11-01Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'BUCKENDOON',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25420,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW2615',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'METHUL',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 18606,
#   'dt_create': '2012-11-21Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW1241',
#   'nsw_locali': '2013-01-23Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'DEEP CREEK',
#   'nsw_loca_3': None,
#   'nsw_loca_4': 2440,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  {'lc_ply_pid': 25564,
#   'dt_create': '2015-12-01Z',
#   'dt_retire': None,
#   'loc_pid': 'NSW3392',
#   'nsw_locali': '2016-01-27Z',
#   'nsw_loca_1': None,
#   'nsw_loca_2': 'RICHMOND VALE',
#   'nsw_loca_3': None,
#   'nsw_loca_4': None,
#   'nsw_loca_5': 'G',
#   'nsw_loca_6': None,
#   'nsw_loca_7': 1},
#  ...]

# %%
#need to get suburb & states out of properies_arr and create sub_df

# %%
# merge sub_df & postcode_df and create sub_post_df

# %%
#merge sub_post_df and SGU_df
